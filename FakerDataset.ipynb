# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijsharma37/Capstone-Navigation-Robot/blob/main/FakerDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.2 MB/s eta 0:00:00
# ...

# %%
import random
import pandas as pd

# List of possible departments and associated symptoms
department_symptoms = {
    "Internal Medicine": [
        "fever", "cough", "sore throat", "fatigue", "nausea", "vomiting",
        "chills", "body aches", "loss of appetite", "chest congestion", "runny nose",
        "wheezing", "swollen lymph nodes",
        "blurred vision", "frequent urination", "low energy",
        "dry cough", "pale skin", "excessive sweating", "unexplained weight loss",
        "tingling sensation", "difficulty swallowing", "persistent headache", "joint swelling",
        "night sweats", "blood in urine"
    ],
    "Orthopedics": [
        "back pain", "knee pain", "shoulder pain", "joint pain", "muscle strain",
        "fracture", "sprain", "torn ligament", "herniated disc", "bursitis",
        "tennis elbow", "carpal tunnel syndrome", "heel pain", "ankle sprain",
        "dislocated joint", "sciatica", "shin splints", "rotator cuff tear",
        "ACL injury", "meniscus tear", "stress fracture", "scoliosis", "osteoarthritis",
        "rheumatoid arthritis", "osteoporosis", "tendinitis", "plantar fasciitis",
        "golfer's elbow", "hip impingement", "broken bone"
    ],
    "Cardiology": [
        "chest pain", "shortness of breath", "palpitations", "high blood pressure", "dizziness",
        "rapid heartbeat", "fatigue", "heartburn", "irregular heartbeat",
        "fainting", "fluid retention", "angina", "heart murmur", "heart palpitations",
        "bradycardia", "hypertension", "hypotension", "peripheral artery disease",
        "myocardial infarction", "congestive heart failure", "arrhythmia", "atherosclerosis",
        "cardiomyopathy", "valve disease", "coronary artery disease", "blood clot",
        "aneurysm", "ventricular fibrillation", "atrial fibrillation"
    ],
    "Neurology": [
        "headache", "numbness", "dizziness", "seizures", "migraine",
        "tingling sensation", "memory loss", "tremors", "difficulty speaking", "vision changes",
        "vertigo", "facial paralysis", "balance problems", "confusion", "weakness",
        "aura", "paralysis", "multiple sclerosis", "amyotrophic lateral sclerosis",
        "cerebral palsy", "Parkinson's disease", "epilepsy", "neuralgia", "neuropathy",
        "myasthenia gravis", "cerebrovascular accident", "concussion", "brain tumor",
        "hemiplegia", "spinal cord injury"
    ],
    "Dermatology": [
        "rash", "itching", "acne", "eczema", "skin irritation",
        "psoriasis", "hives", "rosacea", "dry skin", "sunburn",
        "alopecia", "wrinkles", "melasma", "fungal infection", "athlete's foot",
        "scabies", "mole changes", "skin discoloration", "wart", "skin tags",
        "seborrheic keratosis", "actinic keratosis", "cellulitis", "skin abscess",
        "contact dermatitis", "folliculitis", "lichen planus", "vitiligo", "scleroderma",
        "bullous pemphigoid"
    ],
    "Ophthalmology": [
        "blurry vision", "eye pain", "redness", "itching", "dry eyes",
        "floaters", "flashing lights", "double vision", "watery eyes", "sensitivity to light",
        "glaucoma", "cataracts", "macular degeneration", "conjunctivitis", "corneal abrasion",
        "uveitis", "retinal detachment", "diabetic retinopathy", "ptosis", "strabismus",
        "amblyopia", "color blindness", "nystagmus", "blepharitis", "astigmatism",
        "myopia", "hyperopia", "presbyopia", "keratoconus", "choroiditis"
    ],
    "ENT": [
        "sore throat", "ear pain", "hearing loss", "ringing in ears", "nasal congestion",
        "postnasal drip", "sinus pressure", "dizziness", "earwax buildup", "cough",
        "hoarseness", "nosebleeds", "snoring", "swollen tonsils", "difficulty swallowing",
        "bad breath", "deviated septum", "allergic rhinitis", "otitis media", "tinnitus",
        "tonsillitis", "vertigo", "laryngitis", "epiglottitis", "sinusitis",
        "temporomandibular joint disorder", "pharyngitis", "thyroid disorders",
        "sudden hearing loss"
    ],
    "Gastroenterology": [
        "abdominal pain", "bloating", "nausea", "vomiting", "diarrhea",
        "constipation", "stomach cramps", "acid reflux", "indigestion", "blood in stool",
        "rectal bleeding", "change in bowel habits", "unexplained weight loss", "food intolerance", "gas",
        "black stool", "yellow stool", "pale stool", "bloody stool", "foul-smelling stool",
        "burning stomach", "lower abdominal pain", "upper abdominal pain", "belly button pain", "stomachache",
        "stomach tenderness", "food poisoning", "swollen abdomen", "frequent burping", "heartburn"
    ]
    # Add more departments and symptoms as needed
}

# Generate synthetic dataset with diverse and realistic sentences
num_samples_per_department = 500
data = []
for department, symptoms in department_symptoms.items():
    for _ in range(num_samples_per_department):
        symptom = random.choice(symptoms)
        sentence_patterns = [
            "I have been experiencing {}.",
            "Lately, I've been having {}.",
            "I feel like I might be having {}.",
            "I've noticed {} lately.",
            "I'm dealing with {}.",
            "My {} is bothering me.",
            "It seems like I've got {}.",
            "The {} is getting worse.",
            "I've had {} for a while.",
            "I'm concerned about the {}.",
            "The {} has been bothering me recently.",
            "I've never had {} before.",
            "Is {} a common symptom for {}?",
            "What should I do about my {}?",
            "I've tried treating my {} but it's not getting better."
        ]
        sentence = random.choice(sentence_patterns).format(symptom, department)
        data.append((sentence, department))

# Create a DataFrame from the generated data
df = pd.DataFrame(data, columns=["Sentence", "Department"])

# Save the dataset to a CSV file
df.to_csv("synthetic_realistic_sentence_dataset.csv", index=False)

# %%
# !pip install -U pytorch==0.1.2
# !pip install -U torchtext==0.6.0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: Could not build wheels for pytorch, which is required to install pyproject.toml-based projects
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 585.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.2
#     Uninstalling torchtext-0.15.2:
#       Successfully uninstalled torchtext-0.15.2
# ...

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
dataset = pd.read_csv("synthetic_realistic_sentence_dataset.csv")

# Split the dataset into train and test sets
train_df, test_df = train_test_split(dataset, test_size=0.2, random_state=42)

# Define label mapping
label_map = {label: idx for idx, label in enumerate(dataset["Department"].unique())}

# Encode labels using the label map
train_df["EncodedLabel"] = train_df["Department"].map(label_map)
test_df["EncodedLabel"] = test_df["Department"].map(label_map)

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# Load tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=len(dataset["Department"].unique()))
# Out:
# ...
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sentence = self.data.iloc[idx]["Sentence"]
        department = self.data.iloc[idx]["Department"]
        inputs = self.tokenizer(sentence, padding="max_length", truncation=True, max_length=self.max_length, return_tensors="pt")
        return {"input_ids": inputs["input_ids"].squeeze(), "attention_mask": inputs["attention_mask"].squeeze(), "label": department}

# Create datasets
train_dataset = CustomDataset(train_df, tokenizer)
test_dataset = CustomDataset(test_df, tokenizer)

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 64
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
from transformers import AdamW
import torch.nn as nn

optimizer = AdamW(model.parameters(), lr=1e-5)
criterion = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW
from torch.utils.data import Dataset, DataLoader

# %%
# Training loop
N_EPOCHS = 5

for epoch in range(N_EPOCHS):
    model.train()
    total_loss = 0

    for batch in train_loader:
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["label"]

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        # Convert labels to tensor with correct shape
        label_indices = torch.tensor([label_map[label] for label in labels], dtype=torch.long)

        loss = criterion(logits, label_indices)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    average_loss = total_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{N_EPOCHS}] - Average Loss: {average_loss:.4f}")
# Out:
# Epoch [1/5] - Average Loss: 2.0519
# Epoch [2/5] - Average Loss: 1.6518
# Epoch [3/5] - Average Loss: 0.8868
# Epoch [4/5] - Average Loss: 0.4267
# Epoch [5/5] - Average Loss: 0.2549

# %%
model.save_pretrained("trained_model")
tokenizer.save_pretrained("trained_tokenizer")
# Out:
# ('trained_tokenizer/tokenizer_config.json',
#  'trained_tokenizer/special_tokens_map.json',
#  'trained_tokenizer/vocab.txt',
#  'trained_tokenizer/added_tokens.json')

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# Load the saved tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained("trained_tokenizer")
model = DistilBertForSequenceClassification.from_pretrained("trained_model")

# %%
def classify_sentence(sentence):
    inputs = tokenizer(sentence, padding="max_length", truncation=True, max_length=128, return_tensors="pt")
    logits = model(**inputs).logits
    predicted_label_idx = logits.argmax().item()

    # Map predicted index back to label
    predicted_label = list(label_map.keys())[list(label_map.values()).index(predicted_label_idx)]

    return predicted_label

new_sentence = "I have fever."
predicted_department = classify_sentence(new_sentence)
print(f"Predicted Department: {predicted_department}")
# Out:
# Predicted Department: Internal Medicine
